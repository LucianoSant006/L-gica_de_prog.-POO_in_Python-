# %% [markdown]
# # Manipulação de variáveis e constantes

# %% [markdown]
# coleta.update(coleta2)

# %%
coleta.update(coleta2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-87512a3a464d> in <cell line: 1>()
# ----> 1 coleta.update(coleta2)
#
# NameError: name 'coleta' is not defined

# %%
co = {'adaes':14,'gta':5}
coo = {'abran':13}
co.update(coo)
print(co)
# Out:
# {'adaes': 14, 'gta': 5, 'abran': 13}

# %%
co.items()
# Out:
# dict_items([('adaes', 14), ('gta', 5), ('abran', 13)])

# %%
for especies,  vl in co.items():
  print(f' numero de {especies}  valor de {vl}')
# Out:
#  numero de adaes  valor de 14
#  numero de gta  valor de 5
#  numero de abran  valor de 13

# %%
conjug = ('gta','god of war','pubg','warzone',
          'god of war','pubg','pubg','pubg','warzone')

# %%
print (set(conjug))
# Out:
# {'warzone', 'god of war', 'pubg', 'gta'}

# %%
coleta
del(coleta)['aides']

# %%
coleta
# Out:
# {'aides eygipte': 32, 'aides ipobutes': 22, 'rty': 34}

# %%
coleta ={'aides eygipte':32,'aides ipobutes':22,'aides':14}
coleta['aides']
coleta['aides']= 12
coleta['rty']=34

# %%
coleta2 = {'mano':10, 'ble':20}

# %%
for numero in range(5,0, -1):
  print(numero)
# Out:
# 5
# 4
# 3
# 2
# 1

# %%
numero = 5
while numero < 5:
  print(numero)
  numero +=1
  print('---')

# %%
soma = 0
for i in range(1,6,+1):
  m = float(input(f"dígite sua nota{i}:"))
  soma = soma + m


f = soma / 2
print(f)
# Out:
# dígite sua nota1:10
# dígite sua nota2:10
# dígite sua nota3:10
# dígite sua nota4:10
# dígite sua nota5:10
# 25.0

# %%
soma = 0
t = 3
for i in range(1,11,+1):

  print(f'tabuada 3 X {i} é igual {i * t}')
# Out:
# tabuada 3 X 1 é igual 3
# tabuada 3 X 2 é igual 6
# tabuada 3 X 3 é igual 9
# tabuada 3 X 4 é igual 12
# tabuada 3 X 5 é igual 15
# tabuada 3 X 6 é igual 18
# tabuada 3 X 7 é igual 21
# tabuada 3 X 8 é igual 24
# tabuada 3 X 9 é igual 27
# tabuada 3 X 10 é igual 30

# %%
tupla =('kaka','gaucho','cr7')
tupla.index('kaka')
tupla[2]
# Out:
# 'cr7'

# %%
for i in tupla:
  print(i)
# Out:
# kaka
# gaucho
# cr7

# %%
l1 = ['kaka','pepe','neymar','mozila']
print(l1)
# Out:
# ['kaka', 'pepe', 'neymar', 'mozila']

# %%
l2 = ['kaka','ronaldo feni']
l_2 = l1 + l2
print(l_2)
# Out:
# ['kaka', 'pepe', 'neymar', 'mozila', 'kaka', 'ronaldo feni']

# %%
l1[0:2]
# Out:
# ['kaka', 'pepe']

# %%
l1.append('baloteli')

# %%
print(l1)
# Out:
# ['kaka', 'pepe', 'neymar', 'mozila', 'baloteli']

# %%
dici = {'kaka':12,'péle':10}

dici['kaka']
dici['radisk']= 11
print(dici)
del(dici)['péle']
print(dici)
# Out:
# {'kaka': 12, 'péle': 10, 'radisk': 11}
# {'kaka': 12, 'radisk': 11}

# %%
dici.items()
dici.keys
# Out:
# <function dict.keys>

# %%
numero = 1
while numero < 6:
  print(numero)
  numero +=1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
soma = 0
for numero in range(1,6):
    soma = soma + numero ;
    print(soma)
print(soma)
# Out:
# 1
# 3
# 6
# 10
# 15
# 15

# %%
palavra = 'sorvete'
for letra in palavra:
 # print(letra)
  if letra == 'v':
    print('a letra é v')
# Out:
# a letra é v

# %%
v = int(input('digite sua idade'))
if v > 0 and v<=12:
    print('voce é uma criança e sua idade é',v,'anos')
if v >= 13 and v <= 17:
    print('voce é um adolecente',v,'anos')
if  v > 18:
    print('voce é adulto sua idade é',v)
if v < 0:
          print('idade inválida')
# Out:
# digite sua idade17
# voce é um adolecente 17 anos

# %%
if 1 > 3:
  print('oi')
else:
  print('OI')
# Out:
# oi

# %% [markdown]
# ## Variáveis e constantes
#
# - Por meio de variáveis que um algortimo “guarda” os dados do problema
# - Todo dado que tem a possibilidade de ser alterado no decorrer do tempo deverá ser tratado como uma variável
# - Quando um dado não tem nenhuma possibilidade de variar no decorrer do tempo, deverá ser tratado como constante
#
# Exemplo: calcular a área de um triângulo. Sabemos que a fórmula para o cálculo da área de um triângulo é BASE * ALTURA / 2. **Base** e **altura** são dados que irão variar no decorrer do “tempo de execução”. O número 2 da fórmula é um dado constante, pois sempre terá o mesmo valor
#
# ## Tipo de variáveis
#
# - Inteiros: valores positivos ou negativos, que não possuem uma parte fracionária. Exemplos: 1, 30, 40, 12, -50
# - Float (real): valores positivos ou negativos, que podem possuir uma parte fracionária (também podem ser inteiros). Exemplos: 1.4, 6.7, 10.3, 100, -47
# - Caracteres (char ou string): qualquer elemento presente no teclado. Exemplos: “Maria”, “João”, ‘M’, ‘F’
# - Lógico (boleano): verdadeiro ou falso. Exemplos: true, false, 1, 0

# %% [markdown]
# ## Variáveis inteiras

# %%
numero = -3
numero_jogos = 14
numero_convidados = 15

# %%
numero
# Out:
# -3

# %%
print(numero)
# Out:
# -3

# %%
print(numero, numero_convidados)
# Out:
# -3 15

# %% [markdown]
# ## Variáveis float (ponto flutuante)

# %%
pi = 3.14
numero_euler = 2.71
escala_terremoto = -4.55

# %%
print(pi)
print(numero_euler)
print(escala_terremoto)
# Out:
# 3.14
# 2.71
# -4.55

# %% [markdown]
# ## Strings e chars

# %%
letra = 'a'
palavra ='oi_tudobem'
print('junior',palavra,'boanoite')
# Out:
# junior oi_tudobem boanoite

# %%
idade = input('digite sua idade  ')
print('sua idade é',idade)
ph = input('qual foiu p ph do último solo')
print('o ph foi',ph)
p = 'paragrafo'
m = p.replace('grafo','do')
print(m)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-46bb914cd672> in <cell line: 1>()
# ----> 1 idade = input('digite sua idade  ')
#       2 print('sua idade é',idade)
#       3 ph = input('qual foiu p ph do último solo')
#       4 print('o ph foi',ph)
#       5 p = 'paragrafo'
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
#     896             except Exception as e:
#     897                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
m = float(input('digite sua nota'))
p = str(m).replace('.0','')
print(p)
# Out:
# digite sua nota7.0
# 7

# %%
idade = int(input('qula a sua idade '))
# Out:
# qula a sua idade 19

# %%
idade
# Out:
# 19

# %%
a = 'casaco'
print(a)
maiscula = a.upper()
print(maiscula)
b ='jovem aprendis'
maisculi = b.upper()
print(maisculi)
miniscula = maisculi.lower()
print(miniscula)
c = 'JOAO'
m = c.lower()
print(m)
capital = m.capitalize()
print(capital)
metade_palavra = m[0:3]
print(metade_palavra)
# Out:
# casaco
# CASACO
# JOVEM APRENDIS
# jovem aprendis
# joao
# Joao
# joa

# %%
ultimas_letras = a[3:]
print(ultimas_letras)
# Out:
# aco

# %%
r = a.replace('aco', 'inha')
print(r)
# Out:
# casinha

# %%
c = 'cuscuz'
a = float(input('digite sau nota em dicimal'))
re = str(a).replace('.0','')
print(re)
c.find('s')
# Out:
# digite sau nota em dicimal8.0
# 8
# 2

# %%
letra = 'a'
palavra1 = 'linguagem de programação'
palavra2 = 'Python'

# %%
a = ' casaco '
print(len(a))
j = 'junior'
print (len(j))
f = a.strip()
print(f)
# Out:
# 8
# 6
# casaco

# %%
n1 = 14
n2 = 27

# %%
print(f'dividindo {n1} por {n2} é {n1/n2}')
# Out:
# dividindo 14 por 27 é 0.5185185185185185

# %%
c = 5
b = 3
print(c,b)
# Out:
# 5 3

# %%
c + b
print('a soma é', c + b)
print('a subtracçao', c - b)
print('divisao',c/ b)
print('A MULTIPLICAÇÃO', c*b)
print('divisao é', c / b)
print('o resto é', 10 % 2)
print('5 elevado a 3 é', 5**3)
# Out:
# a soma é 8
# a subtracçao 2
# divisao 1.6666666666666667
# A MULTIPLICAÇÃO 15
# divisao é 1.6666666666666667
# o resto é 0
# 5 elevado a 3 é 125

# %%
import math
math.sqrt(81)
m = int(input('digite o valar da raiz quadrada'))
c = math.sqrt(m)
f = str(c).replace('.0','')
print(f)
# Out:
# digite o valar da raiz quadrada49
# 7

# %%
casos_doencas = 134
nr_habitante =34432
casos_by_habitante = casos_doencas / nr_habitante
print(casos_by_habitante)
round(casos_by_habitante,6)

# %%
vm = int(input('vélocidade média gasta na viagem '))
tg = int(input('forneça o tempo gasto '))

d = vm * tg
lu = d /12

print(f'vélocidade média gasta na viagem é {vm} tempo gasto em média é {tg} distancia percorrida é {r} listos gastos é {lu} litros')
# Out:
# vélocidade média gasta na viagem 50
# forneça o tempo gasto 8
# vélocidade média gasta na viagem é 50 tempo gasto em média é 8 distancia percorrida é 400 listos gastos é 33.333333333333336 litros

# %%
print(letra, palavra1)
# Out:
# a linguagem de programação

# %%
print('Estou aprendendo uma', palavra1)
# Out:
# Estou aprendendo uma linguagem de programação

# %%
print('Esta', palavra1, 'se chama', palavra2)
# Out:
# Esta linguagem de programação se chama Python

# %%
idade = int(input('Digite sua idade:'))
print('Sua idade é ', idade)
# Out:
# Digite sua idade:21
# Sua idade é  21

# %%
pH = float(input('Qual o pH do solo durante a última medição?'))
print('O pH medido foi ', pH)
# Out:
# Qual o pH do solo durante a última medição?2.5
# O pH medido foi  2.5

# %%
nome = str(input('Qual o seu nome?'))
print('Seu nome é', nome)
# Out:
# Qual o seu nome?Jones
# Seu nome é Jones

# %%
idade
# Out:
# 21
